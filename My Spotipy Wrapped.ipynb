# %%
import requests
import spotipy
from spotipy.oauth2 import SpotifyOAuth
import pandas as pd
import time
import datetime
import gspread

# %%
SPOTIPY_CLIENT_ID='YOUR-CLIENT-ID'
SPOTIPY_CLIENT_SECRET='YOUR-CLIENT-SECRET'
SPOTIPY_REDIRECT_URI='http://127.0.0.1:9090'
SCOPE = "user-top-read"

# %%
sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id=SPOTIPY_CLIENT_ID, 
                                               client_secret=SPOTIPY_CLIENT_SECRET, 
                                               redirect_uri=SPOTIPY_REDIRECT_URI, 
                                               scope=SCOPE))

# %%
top_tracks_short = sp.current_user_top_tracks(limit=10, offset=0, time_range="short_term")

# %%
top_tracks_short
# Out:
# {'items': [{'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1uNFoZAHBGtllmzznpCI3s'},
#       'href': 'https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s',
#       'id': '1uNFoZAHBGtllmzznpCI3s',
#       'name': 'Justin Bieber',
#       'type': 'artist',
#       'uri': 'spotify:artist:1uNFoZAHBGtllmzznpCI3s'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5dGWwsZ9iB2Xc3UKR0gif2'},
#     'href': 'https://api.spotify.com/v1/albums/5dGWwsZ9iB2Xc3UKR0gif2',
#     'id': '5dGWwsZ9iB2Xc3UKR0gif2',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e6f407c7f3a0ec98845e4431',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e6f407c7f3a0ec98845e4431',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e6f407c7f3a0ec98845e4431',
#       'width': 64}],
#     'name': 'Justice',
#     'release_date': '2021-03-19',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:5dGWwsZ9iB2Xc3UKR0gif2'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1uNFoZAHBGtllmzznpCI3s'},
#      'href': 'https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s',
#      'id': '1uNFoZAHBGtllmzznpCI3s',
#      'name': 'Justin Bieber',
#      'type': 'artist',
#      'uri': 'spotify:artist:1uNFoZAHBGtllmzznpCI3s'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/20wkVLutqVOYrc0kxFs7rA'},
#      'href': 'https://api.spotify.com/v1/artists/20wkVLutqVOYrc0kxFs7rA',
#      'id': '20wkVLutqVOYrc0kxFs7rA',
#      'name': 'Daniel Caesar',
#      'type': 'artist',
#      'uri': 'spotify:artist:20wkVLutqVOYrc0kxFs7rA'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4fxd5Ee7UefO4CUXgwJ7IP'},
#      'href': 'https://api.spotify.com/v1/artists/4fxd5Ee7UefO4CUXgwJ7IP',
#      'id': '4fxd5Ee7UefO4CUXgwJ7IP',
#      'name': 'Giveon',
#      'type': 'artist',
#      'uri': 'spotify:artist:4fxd5Ee7UefO4CUXgwJ7IP'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 198081,
#    'explicit': True,
#    'external_ids': {'isrc': 'USUM72102636'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4iJyoBOLtHqaGxP12qzhQI'},
#    'href': 'https://api.spotify.com/v1/tracks/4iJyoBOLtHqaGxP12qzhQI',
#    'id': '4iJyoBOLtHqaGxP12qzhQI',
#    'is_local': False,
#    'name': 'Peaches (feat. Daniel Caesar & Giveon)',
#    'popularity': 100,
#    'preview_url': 'https://p.scdn.co/mp3-preview/2d914ef1e42235bd50ba4f1c08f84d84ebb0bebc?cid=5572aac0c3af4c4ab7e2966ec975370f',
#    'track_number': 12,
#    'type': 'track',
#    'uri': 'spotify:track:4iJyoBOLtHqaGxP12qzhQI'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4LEiUm1SRbFMgfqnQTwUbQ'},
#       'href': 'https://api.spotify.com/v1/artists/4LEiUm1SRbFMgfqnQTwUbQ',
#       'id': '4LEiUm1SRbFMgfqnQTwUbQ',
#       'name': 'Bon Iver',
#       'type': 'artist',
#       'uri': 'spotify:artist:4LEiUm1SRbFMgfqnQTwUbQ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1PgfRdl3lPyACfUGH4pquG'},
#     'href': 'https://api.spotify.com/v1/albums/1PgfRdl3lPyACfUGH4pquG',
#     'id': '1PgfRdl3lPyACfUGH4pquG',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273011bea9a2b6b25b84a1f611c',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02011bea9a2b6b25b84a1f611c',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851011bea9a2b6b25b84a1f611c',
#       'width': 64}],
#     'name': '22, A Million',
#     'release_date': '2016-09-30',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:1PgfRdl3lPyACfUGH4pquG'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4LEiUm1SRbFMgfqnQTwUbQ'},
#      'href': 'https://api.spotify.com/v1/artists/4LEiUm1SRbFMgfqnQTwUbQ',
#      'id': '4LEiUm1SRbFMgfqnQTwUbQ',
#      'name': 'Bon Iver',
#      'type': 'artist',
#      'uri': 'spotify:artist:4LEiUm1SRbFMgfqnQTwUbQ'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 309013,
#    'explicit': False,
#    'external_ids': {'isrc': 'US38Y1630008'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/47IklCMgkgWvI4jpkdrop0'},
#    'href': 'https://api.spotify.com/v1/tracks/47IklCMgkgWvI4jpkdrop0',
#    'id': '47IklCMgkgWvI4jpkdrop0',
#    'is_local': False,
#    'name': '8 (circle)',
#    'popularity': 56,
#    'preview_url': 'https://p.scdn.co/mp3-preview/081447adc23dad4f79ba4f1082615d1c56edf5e1?cid=5572aac0c3af4c4ab7e2966ec975370f',
#    'track_number': 8,
#    'type': 'track',
#    'uri': 'spotify:track:47IklCMgkgWvI4jpkdrop0'},
#   {'album': {'album_type': 'SINGLE',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/246dkjvS1zLTtiykXe5h60'},
#       'href': 'https://api.spotify.com/v1/artists/246dkjvS1zLTtiykXe5h60',
#       'id': '246dkjvS1zLTtiykXe5h60',
#       'name': 'Post Malone',
#       'type': 'artist',
#       'uri': 'spotify:artist:246dkjvS1zLTtiykXe5h60'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2xZhidR4y5OPpCRYF09XB4'},
#     'href': 'https://api.spotify.com/v1/albums/2xZhidR4y5OPpCRYF09XB4',
#     'id': '2xZhidR4y5OPpCRYF09XB4',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273d06b152b24e9357e81c460fe',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02d06b152b24e9357e81c460fe',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851d06b152b24e9357e81c460fe',
#       'width': 64}],
#     'name': 'Only Wanna Be With You (Pokémon 25 Version)',
#     'release_date': '2021-02-25',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:2xZhidR4y5OPpCRYF09XB4'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/246dkjvS1zLTtiykXe5h60'},
#      'href': 'https://api.spotify.com/v1/artists/246dkjvS1zLTtiykXe5h60',
#      'id': '246dkjvS1zLTtiykXe5h60',
#      'name': 'Post Malone',
#      'type': 'artist',
#      'uri': 'spotify:artist:246dkjvS1zLTtiykXe5h60'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 241360,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM72102513'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3SawmGBjjq8EOYZJV11cJm'},
#    'href': 'https://api.spotify.com/v1/tracks/3SawmGBjjq8EOYZJV11cJm',
#    'id': '3SawmGBjjq8EOYZJV11cJm',
#    'is_local': False,
#    'name': 'Only Wanna Be With You - Pokémon 25 Version',
#    'popularity': 77,
#    'preview_url': 'https://p.scdn.co/mp3-preview/af2a718ace44faa0c4753f07d05a3046da99c507?cid=5572aac0c3af4c4ab7e2966ec975370f',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:3SawmGBjjq8EOYZJV11cJm'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#       'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#       'id': '06HL4z0CvFAxyc27GXpf02',
#       'name': 'Taylor Swift',
#       'type': 'artist',
#       'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6AORtDjduMM3bupSWzbTSG'},
#     'href': 'https://api.spotify.com/v1/albums/6AORtDjduMM3bupSWzbTSG',
#     'id': '6AORtDjduMM3bupSWzbTSG',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27390fd9741e1838115cd90b3b6',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0290fd9741e1838115cd90b3b6',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485190fd9741e1838115cd90b3b6',
#       'width': 64}],
#     'name': 'evermore (deluxe version)',
#     'release_date': '2021-01-07',
#     'release_date_precision': 'day',
#     'total_tracks': 17,
#     'type': 'album',
#     'uri': 'spotify:album:6AORtDjduMM3bupSWzbTSG'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#      'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#      'id': '06HL4z0CvFAxyc27GXpf02',
#      'name': 'Taylor Swift',
#      'type': 'artist',
#      'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 229840,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUG12004704'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6sQckd3Z8NPxVVKUnavY1F'},
#    'href': 'https://api.spotify.com/v1/tracks/6sQckd3Z8NPxVVKUnavY1F',
#    'id': '6sQckd3Z8NPxVVKUnavY1F',
#    'is_local': False,
#    'name': '‘tis the damn season',
#    'popularity': 64,
#    'preview_url': 'https://p.scdn.co/mp3-preview/4765b803b4c0bc1b9ef1c4d9bb4b9b91299017d5?cid=5572aac0c3af4c4ab7e2966ec975370f',
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:6sQckd3Z8NPxVVKUnavY1F'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#       'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#       'id': '06HL4z0CvFAxyc27GXpf02',
#       'name': 'Taylor Swift',
#       'type': 'artist',
#       'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2fenSS68JI1h4Fo296JfGr'},
#     'href': 'https://api.spotify.com/v1/albums/2fenSS68JI1h4Fo296JfGr',
#     'id': '2fenSS68JI1h4Fo296JfGr',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27395f754318336a07e85ec59bc',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0295f754318336a07e85ec59bc',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485195f754318336a07e85ec59bc',
#       'width': 64}],
#     'name': 'folklore',
#     'release_date': '2020-07-24',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:2fenSS68JI1h4Fo296JfGr'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#      'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#      'id': '06HL4z0CvFAxyc27GXpf02',
#      'name': 'Taylor Swift',
#      'type': 'artist',
#      'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 210251,
#    'explicit': True,
#    'external_ids': {'isrc': 'USUG12002835'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0Jlcvv8IykzHaSmj49uNW8'},
#    'href': 'https://api.spotify.com/v1/tracks/0Jlcvv8IykzHaSmj49uNW8',
#    'id': '0Jlcvv8IykzHaSmj49uNW8',
#    'is_local': False,
#    'name': 'the 1',
#    'popularity': 77,
#    'preview_url': 'https://p.scdn.co/mp3-preview/efebd9d9b761b7685da9264c637a1db1cd994f19?cid=5572aac0c3af4c4ab7e2966ec975370f',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:0Jlcvv8IykzHaSmj49uNW8'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#       'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#       'id': '06HL4z0CvFAxyc27GXpf02',
#       'name': 'Taylor Swift',
#       'type': 'artist',
#       'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2fenSS68JI1h4Fo296JfGr'},
#     'href': 'https://api.spotify.com/v1/albums/2fenSS68JI1h4Fo296JfGr',
#     'id': '2fenSS68JI1h4Fo296JfGr',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27395f754318336a07e85ec59bc',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0295f754318336a07e85ec59bc',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485195f754318336a07e85ec59bc',
#       'width': 64}],
#     'name': 'folklore',
#     'release_date': '2020-07-24',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:2fenSS68JI1h4Fo296JfGr'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#      'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#      'id': '06HL4z0CvFAxyc27GXpf02',
#      'name': 'Taylor Swift',
#      'type': 'artist',
#      'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 261922,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUG12002842'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3hUxzQpSfdDqwM3ZTFQY0K'},
#    'href': 'https://api.spotify.com/v1/tracks/3hUxzQpSfdDqwM3ZTFQY0K',
#    'id': '3hUxzQpSfdDqwM3ZTFQY0K',
#    'is_local': False,
#    'name': 'august',
#    'popularity': 76,
#    'preview_url': 'https://p.scdn.co/mp3-preview/bdd773c753764b9942a002d8700eb001d339d6ad?cid=5572aac0c3af4c4ab7e2966ec975370f',
#    'track_number': 8,
#    'type': 'track',
#    'uri': 'spotify:track:3hUxzQpSfdDqwM3ZTFQY0K'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#       'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#       'id': '06HL4z0CvFAxyc27GXpf02',
#       'name': 'Taylor Swift',
#       'type': 'artist',
#       'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6AORtDjduMM3bupSWzbTSG'},
#     'href': 'https://api.spotify.com/v1/albums/6AORtDjduMM3bupSWzbTSG',
#     'id': '6AORtDjduMM3bupSWzbTSG',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27390fd9741e1838115cd90b3b6',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0290fd9741e1838115cd90b3b6',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485190fd9741e1838115cd90b3b6',
#       'width': 64}],
#     'name': 'evermore (deluxe version)',
#     'release_date': '2021-01-07',
#     'release_date_precision': 'day',
#     'total_tracks': 17,
#     'type': 'album',
#     'uri': 'spotify:album:6AORtDjduMM3bupSWzbTSG'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#      'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#      'id': '06HL4z0CvFAxyc27GXpf02',
#      'name': 'Taylor Swift',
#      'type': 'artist',
#      'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 215920,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUG12004716'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5VYWxXUpxuxEmCqMLDqICo'},
#    'href': 'https://api.spotify.com/v1/tracks/5VYWxXUpxuxEmCqMLDqICo',
#    'id': '5VYWxXUpxuxEmCqMLDqICo',
#    'is_local': False,
#    'name': 'long story short',
#    'popularity': 63,
#    'preview_url': 'https://p.scdn.co/mp3-preview/5792d4467a069b1de7ee3e5141a697942a2d4b05?cid=5572aac0c3af4c4ab7e2966ec975370f',
#    'track_number': 12,
#    'type': 'track',
#    'uri': 'spotify:track:5VYWxXUpxuxEmCqMLDqICo'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hEurMDQu99nJRq8pTxO14'},
#       'href': 'https://api.spotify.com/v1/artists/0hEurMDQu99nJRq8pTxO14',
#       'id': '0hEurMDQu99nJRq8pTxO14',
#       'name': 'John Mayer',
#       'type': 'artist',
#       'uri': 'spotify:artist:0hEurMDQu99nJRq8pTxO14'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6S0BIiWtnqU0PtumXMpin0'},
#     'href': 'https://api.spotify.com/v1/albums/6S0BIiWtnqU0PtumXMpin0',
#     'id': '6S0BIiWtnqU0PtumXMpin0',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2733c6bbf44de57c6eb51818694',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e023c6bbf44de57c6eb51818694',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048513c6bbf44de57c6eb51818694',
#       'width': 64}],
#     'name': 'Born and Raised',
#     'release_date': '2012-05-18',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:6S0BIiWtnqU0PtumXMpin0'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hEurMDQu99nJRq8pTxO14'},
#      'href': 'https://api.spotify.com/v1/artists/0hEurMDQu99nJRq8pTxO14',
#      'id': '0hEurMDQu99nJRq8pTxO14',
#      'name': 'John Mayer',
#      'type': 'artist',
#      'uri': 'spotify:artist:0hEurMDQu99nJRq8pTxO14'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 307986,
#    'explicit': False,
#    'external_ids': {'isrc': 'USSM11201483'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5S3NpJBqacEUrxceiAy5lI'},
#    'href': 'https://api.spotify.com/v1/tracks/5S3NpJBqacEUrxceiAy5lI',
#    'id': '5S3NpJBqacEUrxceiAy5lI',
#    'is_local': False,
#    'name': "Walt Grace's Submarine Test, January 1967",
#    'popularity': 49,
#    'preview_url': 'https://p.scdn.co/mp3-preview/14148bdc7d56fdeab269bda16749b020e5dd1069?cid=5572aac0c3af4c4ab7e2966ec975370f',
#    'track_number': 9,
#    'type': 'track',
#    'uri': 'spotify:track:5S3NpJBqacEUrxceiAy5lI'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#       'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#       'id': '06HL4z0CvFAxyc27GXpf02',
#       'name': 'Taylor Swift',
#       'type': 'artist',
#       'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6AORtDjduMM3bupSWzbTSG'},
#     'href': 'https://api.spotify.com/v1/albums/6AORtDjduMM3bupSWzbTSG',
#     'id': '6AORtDjduMM3bupSWzbTSG',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27390fd9741e1838115cd90b3b6',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0290fd9741e1838115cd90b3b6',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485190fd9741e1838115cd90b3b6',
#       'width': 64}],
#     'name': 'evermore (deluxe version)',
#     'release_date': '2021-01-07',
#     'release_date_precision': 'day',
#     'total_tracks': 17,
#     'type': 'album',
#     'uri': 'spotify:album:6AORtDjduMM3bupSWzbTSG'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#      'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#      'id': '06HL4z0CvFAxyc27GXpf02',
#      'name': 'Taylor Swift',
#      'type': 'artist',
#      'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 225880,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUG12004710'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/66tOfHVH3aUrscg8vExRV4'},
#    'href': 'https://api.spotify.com/v1/tracks/66tOfHVH3aUrscg8vExRV4',
#    'id': '66tOfHVH3aUrscg8vExRV4',
#    'is_local': False,
#    'name': 'dorothea',
#    'popularity': 62,
#    'preview_url': 'https://p.scdn.co/mp3-preview/26b9863302db7bcc6dd93551b9ff0095b6c0dd61?cid=5572aac0c3af4c4ab7e2966ec975370f',
#    'track_number': 8,
#    'type': 'track',
#    'uri': 'spotify:track:66tOfHVH3aUrscg8vExRV4'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#       'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#       'id': '06HL4z0CvFAxyc27GXpf02',
#       'name': 'Taylor Swift',
#       'type': 'artist',
#       'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4hDok0OAJd57SGIT8xuWJH'},
#     'href': 'https://api.spotify.com/v1/albums/4hDok0OAJd57SGIT8xuWJH',
#     'id': '4hDok0OAJd57SGIT8xuWJH',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273a48964b5d9a3d6968ae3e0de',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02a48964b5d9a3d6968ae3e0de',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851a48964b5d9a3d6968ae3e0de',
#       'width': 64}],
#     'name': "Fearless (Taylor's Version)",
#     'release_date': '2021-04-09',
#     'release_date_precision': 'day',
#     'total_tracks': 26,
#     'type': 'album',
#     'uri': 'spotify:album:4hDok0OAJd57SGIT8xuWJH'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#      'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#      'id': '06HL4z0CvFAxyc27GXpf02',
#      'name': 'Taylor Swift',
#      'type': 'artist',
#      'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/0u2FHSq3ln94y5Q57xazwf'},
#      'href': 'https://api.spotify.com/v1/artists/0u2FHSq3ln94y5Q57xazwf',
#      'id': '0u2FHSq3ln94y5Q57xazwf',
#      'name': 'Keith Urban',
#      'type': 'artist',
#      'uri': 'spotify:artist:0u2FHSq3ln94y5Q57xazwf'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 189495,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUG12100640'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7eResoqEJJAVTkQYSqvO3P'},
#    'href': 'https://api.spotify.com/v1/tracks/7eResoqEJJAVTkQYSqvO3P',
#    'id': '7eResoqEJJAVTkQYSqvO3P',
#    'is_local': False,
#    'name': 'That’s When (feat. Keith Urban) (Taylor’s Version) (From The Vault)',
#    'popularity': 77,
#    'preview_url': 'https://p.scdn.co/mp3-preview/56f0a105246543e29ba4906e0ae17d478e4d41f8?cid=5572aac0c3af4c4ab7e2966ec975370f',
#    'track_number': 24,
#    'type': 'track',
#    'uri': 'spotify:track:7eResoqEJJAVTkQYSqvO3P'}],
#  'total': 50,
#  'limit': 10,
#  'offset': 0,
#  'previous': None,
#  'href': 'https://api.spotify.com/v1/me/top/tracks?limit=10&offset=0&time_range=short_term',
#  'next': 'https://api.spotify.com/v1/me/top/tracks?limit=10&offset=10&time_range=short_term'}

# %%
top_tracks_short = sp.current_user_top_tracks(limit=20, offset=0, time_range="short_term")

# %%
type(top_tracks_short)
# Out:
# dict

# %%
def get_track_ids(time_frame):
    track_ids = []
    for song in time_frame['items']:
        track_ids.append(song['id'])
    return track_ids

# %%
track_ids = get_track_ids(top_tracks_short)

# %%
track_ids
# Out:
# ['4iJyoBOLtHqaGxP12qzhQI',
#  '47IklCMgkgWvI4jpkdrop0',
#  '3SawmGBjjq8EOYZJV11cJm',
#  '6sQckd3Z8NPxVVKUnavY1F',
#  '0Jlcvv8IykzHaSmj49uNW8',
#  '3hUxzQpSfdDqwM3ZTFQY0K',
#  '5VYWxXUpxuxEmCqMLDqICo',
#  '5S3NpJBqacEUrxceiAy5lI',
#  '66tOfHVH3aUrscg8vExRV4',
#  '7eResoqEJJAVTkQYSqvO3P',
#  '6KJqZcs9XDgVck7Lg9QOTC',
#  '2TjnCxxQRYn56Ye8gkUKiW',
#  '476V2d6iA2tWXgQboKmTtA',
#  '5ri4zqtWhG07hIuNNDWP76',
#  '2cWHN0WK52RGAWHgaDamUA',
#  '3Dby3p1m6IOZn2gIIqECgK',
#  '3lB0GMiI5KxDbTOG8V3bOx',
#  '6uwfVkaOM1mcMkFmSn35ix',
#  '0qdQUeKVyevrbKhAo0ibxS',
#  '29HaKOpeLSYvqdFyEQSRdj']

# %%
track_id = '4iJyoBOLtHqaGxP12qzhQI'

# %%
def get_track_features(id):
    meta = sp.track(id)
    # meta
    name = meta['name']
    album = meta['album']['name']
    artist = meta['album']['artists'][0]['name']
    spotify_url = meta['external_urls']['spotify']
    album_cover = meta['album']['images'][0]['url']
    track_info = [name, album, artist, spotify_url, album_cover]
    return track_info

# %%
get_track_features(track_id)
# Out:
# ['Peaches (feat. Daniel Caesar & Giveon)',
#  'Justice',
#  'Justin Bieber',
#  'https://open.spotify.com/track/4iJyoBOLtHqaGxP12qzhQI',
#  'https://i.scdn.co/image/ab67616d0000b273e6f407c7f3a0ec98845e4431']

# %%
# loop over track ids 
tracks = []
for i in range(len(track_ids)):
    time.sleep(.5)
    track = get_track_features(track_ids[i])
    tracks.append(track)

# %%
tracks
# Out:
# [['Peaches (feat. Daniel Caesar & Giveon)',
#   'Justice',
#   'Justin Bieber',
#   'https://open.spotify.com/track/4iJyoBOLtHqaGxP12qzhQI',
#   'https://i.scdn.co/image/ab67616d0000b273e6f407c7f3a0ec98845e4431'],
#  ['8 (circle)',
#   '22, A Million',
#   'Bon Iver',
#   'https://open.spotify.com/track/47IklCMgkgWvI4jpkdrop0',
#   'https://i.scdn.co/image/ab67616d0000b273011bea9a2b6b25b84a1f611c'],
#  ['Only Wanna Be With You - Pokémon 25 Version',
#   'Only Wanna Be With You (Pokémon 25 Version)',
#   'Post Malone',
#   'https://open.spotify.com/track/3SawmGBjjq8EOYZJV11cJm',
#   'https://i.scdn.co/image/ab67616d0000b273d06b152b24e9357e81c460fe'],
#  ['‘tis the damn season',
#   'evermore (deluxe version)',
#   'Taylor Swift',
#   'https://open.spotify.com/track/6sQckd3Z8NPxVVKUnavY1F',
#   'https://i.scdn.co/image/ab67616d0000b27390fd9741e1838115cd90b3b6'],
#  ['the 1',
#   'folklore',
#   'Taylor Swift',
#   'https://open.spotify.com/track/0Jlcvv8IykzHaSmj49uNW8',
#   'https://i.scdn.co/image/ab67616d0000b27395f754318336a07e85ec59bc'],
#  ['august',
#   'folklore',
#   'Taylor Swift',
#   'https://open.spotify.com/track/3hUxzQpSfdDqwM3ZTFQY0K',
#   'https://i.scdn.co/image/ab67616d0000b27395f754318336a07e85ec59bc'],
#  ['long story short',
#   'evermore (deluxe version)',
#   'Taylor Swift',
#   'https://open.spotify.com/track/5VYWxXUpxuxEmCqMLDqICo',
#   'https://i.scdn.co/image/ab67616d0000b27390fd9741e1838115cd90b3b6'],
#  ["Walt Grace's Submarine Test, January 1967",
#   'Born and Raised',
#   'John Mayer',
#   'https://open.spotify.com/track/5S3NpJBqacEUrxceiAy5lI',
#   'https://i.scdn.co/image/ab67616d0000b2733c6bbf44de57c6eb51818694'],
#  ['dorothea',
#   'evermore (deluxe version)',
#   'Taylor Swift',
#   'https://open.spotify.com/track/66tOfHVH3aUrscg8vExRV4',
#   'https://i.scdn.co/image/ab67616d0000b27390fd9741e1838115cd90b3b6'],
#  ['That’s When (feat. Keith Urban) (Taylor’s Version) (From The Vault)',
#   "Fearless (Taylor's Version)",
#   'Taylor Swift',
#   'https://open.spotify.com/track/7eResoqEJJAVTkQYSqvO3P',
#   'https://i.scdn.co/image/ab67616d0000b273a48964b5d9a3d6968ae3e0de'],
#  ['seven',
#   'folklore',
#   'Taylor Swift',
#   'https://open.spotify.com/track/6KJqZcs9XDgVck7Lg9QOTC',
#   'https://i.scdn.co/image/ab67616d0000b27395f754318336a07e85ec59bc'],
#  ['Desperado - 2013 Remaster',
#   'Desperado (2013 Remaster)',
#   'Eagles',
#   'https://open.spotify.com/track/2TjnCxxQRYn56Ye8gkUKiW',
#   'https://i.scdn.co/image/ab67616d0000b2732d73b1bb77cee09f0278be04'],
#  ['Father And Son',
#   'Tea For The Tillerman (Remastered 2020)',
#   'Yusuf / Cat Stevens',
#   'https://open.spotify.com/track/476V2d6iA2tWXgQboKmTtA',
#   'https://i.scdn.co/image/ab67616d0000b273e7248738c2f7ce3b5584b15d'],
#  ['Fly Away',
#   'Fly Away',
#   'Tones And I',
#   'https://open.spotify.com/track/5ri4zqtWhG07hIuNNDWP76',
#   'https://i.scdn.co/image/ab67616d0000b2738fb79948870fc9314eccac4b'],
#  ['Take It to the Limit - 2013 Remaster',
#   'One of These Nights (2013 Remaster)',
#   'Eagles',
#   'https://open.spotify.com/track/2cWHN0WK52RGAWHgaDamUA',
#   'https://i.scdn.co/image/ab67616d0000b2735d0a8e54aba5181c79593b94'],
#  ['gold rush',
#   'evermore (deluxe version)',
#   'Taylor Swift',
#   'https://open.spotify.com/track/3Dby3p1m6IOZn2gIIqECgK',
#   'https://i.scdn.co/image/ab67616d0000b27390fd9741e1838115cd90b3b6'],
#  ['waves - Tame Impala Remix',
#   'Rogue Waves',
#   'Miguel',
#   'https://open.spotify.com/track/3lB0GMiI5KxDbTOG8V3bOx',
#   'https://i.scdn.co/image/ab67616d0000b273c4daf0fda7e16ba5b0f86830'],
#  ['no body, no crime (feat. HAIM)',
#   'evermore (deluxe version)',
#   'Taylor Swift',
#   'https://open.spotify.com/track/6uwfVkaOM1mcMkFmSn35ix',
#   'https://i.scdn.co/image/ab67616d0000b27390fd9741e1838115cd90b3b6'],
#  ['My Sweet Lord - Remastered 2014',
#   'All Things Must Pass (Remastered 2014)',
#   'George Harrison',
#   'https://open.spotify.com/track/0qdQUeKVyevrbKhAo0ibxS',
#   'https://i.scdn.co/image/ab67616d0000b273acc11d868a59008935e72299'],
#  ['Teach Your Children',
#   'Deja Vu',
#   'Crosby, Stills, Nash & Young',
#   'https://open.spotify.com/track/29HaKOpeLSYvqdFyEQSRdj',
#   'https://i.scdn.co/image/ab67616d0000b27385ec0264a22d007c1cbd780c']]

# %%
# create dataset
df = pd.DataFrame(tracks, columns = ['name', 'album', 'artist', 'spotify_url', 'album_cover'])
df.head(5)
# Out:
#                                           name  \
# 0       Peaches (feat. Daniel Caesar & Giveon)
# 1                                   8 (circle)
# 2  Only Wanna Be With You - Pokémon 25 Version
# 3                         ‘tis the damn season
# 4                                        the 1
#
#                                          album         artist  \
# 0                                      Justice  Justin Bieber
# 1                                22, A Million       Bon Iver
# 2  Only Wanna Be With You (Pokémon 25 Version)    Post Malone
# 3                    evermore (deluxe version)   Taylor Swift
# 4                                     folklore   Taylor Swift
#
#                                          spotify_url  \
# 0  https://open.spotify.com/track/4iJyoBOLtHqaGxP...
# 1  https://open.spotify.com/track/47IklCMgkgWvI4j...
# 2  https://open.spotify.com/track/3SawmGBjjq8EOYZ...
# 3  https://open.spotify.com/track/6sQckd3Z8NPxVVK...
# 4  https://open.spotify.com/track/0Jlcvv8IykzHaSm...
#
#                                          album_cover
# 0  https://i.scdn.co/image/ab67616d0000b273e6f407...
# 1  https://i.scdn.co/image/ab67616d0000b273011bea...
# 2  https://i.scdn.co/image/ab67616d0000b273d06b15...
# 3  https://i.scdn.co/image/ab67616d0000b27390fd97...
# 4  https://i.scdn.co/image/ab67616d0000b27395f754...

# %%
gc = gspread.service_account(filename='my-spotify-wrapped-test-ad510490b281.json')

# %%
sh = gc.open("My Spotify Wrapped")

# %%
worksheet = sh.worksheet("short_term")

# %%
val = worksheet.acell('B5').value
val
# Out:
# 'FIND ME!'

# %%
# worksheet.update([dataframe.columns.values.tolist()] + dataframe.values.tolist())

# %%
# insert into sheet
def insert_to_gsheet(track_ids):
    # loop over track ids 
    tracks = []
    for i in range(len(track_ids)):
        time.sleep(.5)
        track = get_track_features(track_ids[i])
        tracks.append(track)
    # create dataframe
    df = pd.DataFrame(tracks, columns = ['name', 'album', 'artist', 'spotify_url', 'album_cover'])
    # insert into google sheet
    gc = gspread.service_account(filename='my-spotify-wrapped-test-ad510490b281.json')
    sh = gc.open('My Spotify Wrapped')
    worksheet = sh.worksheet(f'{time_period}')
    worksheet.update([df.columns.values.tolist()] + df.values.tolist())
    print('Done')

# %%
time_ranges = ['short_term', 'medium_term', 'long_term']
for time_period in time_ranges:
    top_tracks = sp.current_user_top_tracks(limit=20, offset=0, time_range=time_period)
    track_ids = get_track_ids(top_tracks)
    insert_to_gsheet(track_ids)
# Out:
# Done
# Done
# Done
